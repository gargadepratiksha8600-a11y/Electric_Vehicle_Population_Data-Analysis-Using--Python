# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\dell\Downloads\archive\Electric_Vehicle_Population_Data.csv")

# %%
df
# Out:
#         VIN (1-10)    County               City State  Postal Code  \
# 0       1N4BZ0CP5G      King            Seattle    WA      98125.0
# 1       KNDJX3AEXG      King             Renton    WA      98058.0
# 2       5YJ3E1EB2J      King            Seattle    WA      98115.0
# 3       1C4RJXN64R    Kitsap          Bremerton    WA      98312.0
# 4       5YJ3E1EB1J  Thurston            Olympia    WA      98512.0
# ...            ...       ...                ...   ...          ...
# 247339  7G2CEHED0R      King          Newcastle    WA      98056.0
# 247340  1C4RJYC65R    Pierce           Puyallup    WA      98374.0
# 247341  7SAYGDEE0P      King            Bothell    WA      98011.0
# 247342  KNDPYDAH9P    Kitsap  Bainbridge Island    WA      98110.0
# 247343  KNDPZDAH8P   Whatcom         Bellingham    WA      98226.0
#
#         Model Year    Make           Model  \
# 0             2016  NISSAN            LEAF
# 1             2016     KIA            SOUL
# ...

# %%
#1.Get the most common 'Make'  and their counts
make_count = df['Make'].value_counts()
make_count
# Out:
# Make
# TESLA                     105001
# CHEVROLET                  17840
# NISSAN                     15892
# FORD                       13270
# KIA                        11978
# BMW                        10370
# TOYOTA                     10245
# HYUNDAI                     8048
# RIVIAN                      7491
# VOLVO                       6428
# VOLKSWAGEN                  6427
# JEEP                        6139
# AUDI                        4547
# CHRYSLER                    3479
# MERCEDES-BENZ               2728
# HONDA                       2377
# SUBARU                      2102
# PORSCHE                     1655
# POLESTAR                    1424
# CADILLAC                    1377
# MAZDA                       1182
# MINI                        1180
# LEXUS                       1104
# MITSUBISHI                  1096
# FIAT                         845
# LUCID                        423
# GMC                          421
# LINCOLN                      396
# ...

# %%
#2.get the first top five make and their count
top_five = df['Make'].value_counts().head(5)
top_five
# Out:
# Make
# TESLA        105001
# CHEVROLET     17840
# NISSAN        15892
# FORD          13270
# KIA           11978
# Name: count, dtype: int64

# %%
#3.get the least five make and their count 
least= df['Make'].value_counts().tail(5)
least
# Out:
# Make
# BRIGHTDROP                5
# AZURE DYNAMICS            4
# VINFAST                   2
# MULLEN AUTOMOTIVE INC.    2
# WHEEGO ELECTRIC CARS      2
# Name: count, dtype: int64

# %%
#4.what is the avrage electric range
range_avg= df['Electric Range'].mean()
range_avg
# Out:
# 44.64565913538516

# %%
#5.what is the avrage Base MSRP
base_avg= df['Base MSRP'].mean()
base_avg
# Out:
# 740.2063083243033

# %%
#6.get the total count of model
model= df['Model'].value_counts()
model
# Out:
# Model
# MODEL Y        51528
# MODEL 3        37427
# LEAF           13950
# MODEL S         7912
# BOLT EV         7463
#                ...
# ONE                2
# S E-TRON GT        2
# 918                1
# SL-CLASS           1
# CONTINENTAL        1
# Name: count, Length: 177, dtype: int64

# %%
#7.get the top five model 
top_model= df['Model'].value_counts().head(5)
top_model
# Out:
# Model
# MODEL Y    51528
# MODEL 3    37427
# LEAF       13950
# MODEL S     7912
# BOLT EV     7463
# Name: count, dtype: int64

# %%
#8.get the maximum Base msrp
max_msrp= df['Base MSRP'].max()
max_msrp
# Out:
# 845000.0

# %%
#9.get the min Base msrp
min_msrp= df['Base MSRP'].min()
min_msrp
# Out:
# 0.0

# %%
#10.get the electric vehicle type
vehicle_type = df['Electric Vehicle Type'].value_counts()
vehicle_type
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            197146
# Plug-in Hybrid Electric Vehicle (PHEV)     50198
# Name: count, dtype: int64

# %%
#11 get the city count
city=df['City'].value_counts()
city
# Out:
# City
# Seattle        39524
# Bellevue       12124
# Vancouver       9172
# Redmond         8606
# Bothell         8158
#                ...
# Saint Marys        1
# Ventura            1
# Killeen            1
# Dixie              1
# Hyde Park          1
# Name: count, Length: 807, dtype: int64

# %%
#get the country count
country= df['County'].value_counts()
country
# Out:
# County
# King            122819
# Snohomish        30587
# Pierce           20534
# Clark            15055
# Thurston          9081
#                  ...
# Tarrant              1
# Cochise              1
# Medina               1
# Calvert              1
# Williamsburg         1
# Name: count, Length: 215, dtype: int64

# %%
#13 get the max electric range
max_range = df['Electric Range'].max()
max_range
# Out:
# 337.0

# %%
# 14Count missing (null) values in 'Vehicle Location'
null_location= df['Vehicle Location'].isnull().sum()
null_location
# Out:
# 11

# %%
#15 count of vehicle per model ye
year= df['Model Year'].value_counts().sort_index()
year
# Out:
# Model Year
# 2000        8
# 2002        2
# 2003        1
# 2008       17
# 2010       23
# 2011      656
# 2012     1462
# 2013     4168
# 2014     3364
# 2015     4613
# 2016     5302
# 2017     8755
# 2018    14504
# 2019    11055
# 2020    12390
# 2021    20794
# 2022    29337
# 2023    59088
# 2024    49799
# 2025    20820
# 2026     1186
# Name: count, dtype: int64

# %%
#16# Count of each CAFV eligibility status
cafv_eligibility_count = df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()
cafv_eligibility_count
# Out:
# Clean Alternative Fuel Vehicle (CAFV) Eligibility
# Eligibility unknown as battery range has not been researched    149634
# Clean Alternative Fuel Vehicle Eligible                          74523
# Not eligible due to low battery range                            23187
# Name: count, dtype: int64

# %%
# Get percentage distribution of Make
make_percentage = df['Make'].value_counts(normalize=True) * 100
make_percentage
# Out:
# Make
# TESLA                     42.451404
# CHEVROLET                  7.212627
# NISSAN                     6.425060
# FORD                       5.364998
# KIA                        4.842648
# BMW                        4.192542
# TOYOTA                     4.142005
# HYUNDAI                    3.253768
# RIVIAN                     3.028576
# VOLVO                      2.598810
# VOLKSWAGEN                 2.598405
# JEEP                       2.481968
# AUDI                       1.838330
# CHRYSLER                   1.406543
# MERCEDES-BENZ              1.102917
# HONDA                      0.961010
# SUBARU                     0.849829
# PORSCHE                    0.669109
# POLESTAR                   0.575716
# CADILLAC                   0.556715
# MAZDA                      0.477877
# MINI                       0.477068
# LEXUS                      0.446342
# MITSUBISHI                 0.443108
# FIAT                       0.341629
# LUCID                      0.171017
# ...

# %%
#get the std of electric range
std_dev = df['Electric Range'].std()
std_dev
# Out:
# 82.94531498774072

# %%
#19.get the count of vehicle range > 200
vehicle_range = (df['Electric Range'] > 200).sum()
print("Number of vehicles with Electric Range > 200:", vehicle_range)
# Out:
# Number of vehicles with Electric Range > 200: 32106

# %%
# 20. Median Model Year
print("Median Model Year:", df['Model Year'].median())
# Out:
# Median Model Year: 2023.0

# %%
# 21.get the unique model year
year = df['Model Year'].nunique()
year
# Out:
# 21

# %%
#22 get the unique no of make
make = df['Make'].nunique()
make
# Out:
# 46

# %%
# 23. Check for nulls
print("Missing values per column:\n", df.isnull().sum())
# Out:
# Missing values per column:
#  VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                        20
# Base MSRP                                             20
# Legislative District                                 553
# DOL Vehicle ID                                         0
# Vehicle Location                                      11
# Electric Utility                                       4
# ...

# %%
# 24. Top Counties
print("Top 5 Counties:\n", df['County'].value_counts().head(5))
# Out:
# Top 5 Counties:
#  County
# King         122819
# Snohomish     30587
# Pierce        20534
# Clark         15055
# Thurston       9081
# Name: count, dtype: int64

# %%
# 25. Rare Models (appear only once)
rare_models = df['Model'].value_counts()
print("Number of rare Models (appear once):", (rare_models == 1).sum())
# Out:
# Number of rare Models (appear once): 3

# %%
#vehicle made before 2015
year=(df['Model Year'] < 2015).sum()
year
# Out:
# 9701

# %%
import seaborn as sns

# %%
df['Make'].value_counts().head(10).plot(kind= 'bar')
# Out:
# <Axes: xlabel='Make'>

# %%
df['Electric Vehicle Type'].value_counts().plot(
    kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Electric Range'].hist(bins=50)
# Out:
# <Axes: >
